# %% [markdown]
# # Final Project - Korean to English Translation
#
# - Sequence to Sequence 모델의 대표적인 한국어-영어 번역을 Encoder-decoder, Attention, Convolution, 그리고 Transformers 기반으로 구현
# - 수업시간에 살펴본 Pytorch Seq to Seq 모델 (https://github.com/bentrevett/pytorch-seq2seq)을 참조로 하여 한국어와 영어 형태소분석되고 의존관계로 되어 있는 파일을 프로세싱하여 두 언어의 parallel 데이터 쌍으로 만들고 이를 학습하여 모델별로 Perplexity가 어떻게 달라지는지 살펴 보고, 가장 성능이 좋은 모델을 근간으로 해서 Inference로 한국어 문장을 입력하면 대응되는 영어 번역이 출력될 수 있도록 구현
# - 반드시 다음 세 모델에 대해서 PPL와 BLEU score가  다 체크되어야 함. (Packed) Encoder-Decoder, Convolutional Seq to Seq, Transformers ...
# - 세 모델 중에 학습이 제대로 이루어지지 않는 경우, PPL이나 BLEU가 문제가 있는 경우 이를 Fix하려고 시도해 보라.
# - Inference시에 unk인 단어를 로마자화해서 번역에 나타날 수 있도록 시도해 볼 것(참고할 수 있는 사이트 중 하나 https://github.com/osori/korean-romanizer)
#
# - 개인적으로 하거나 최대 두명까지 그룹 허용.
# - 이 노트북 화일에 이름을 변경하여 작업하고 제출. 제출시 화일명을 Assignment4_[DS또는 CL]_학과_이름.ipynb

# %% [markdown]
# ## Data 1
# - 첨부된 ko-en-en.parse.syn은 330,974 한국어 문장에 대응되는 영어문장이 품사와 구문분석이 되어 있는 파일이고 ko-en-ko.parse.syn은 이에 대응되는 한국어 문장이 형태소와 구문분석이 되어 있는 파일이다.
#
# (ROOT (S (NP (NNP Flight) (NNP 007)) (VP (MD will) (VP (VB stay) (PP (IN on) (NP (NP (DT the) (NN ground)) (PP (IN for) (NP (CD one) (NN hour))))))) (. .)))
#
#
# <id 1>
# <sent 1>
# 1       2       NP      777/SN
# 2       6       NP_SBJ  항공편/NNG|은/JX
# 3       4       NP      1/SN|시간/NNG
# 4       6       NP_AJT  동안/NNG
# 5       6       NP_AJT  지상/NNG|에/JKB
# 6       7       VP      머물/VV|게/EC
# 7       0       VP      되/VV|ㅂ니다/EF|./SF
# </sent>
# </id>
#
#     - 이 두 파일을 프로세싱하여 한-영 병렬 데이터로 만들고 이를 학습 및 테스트 데이터로 사용한다.
#     - Hint: 구조화된 데이터를 프로세싱하기 위해서는 nltk의 모듈을 사용할 수 있다.
#
#     - 한국어 형태소 분석된 단위를 어절별로 결합할 수 있고, 분석된 채로 그대로 사용할 수도 있다.
#     - 두 언어의 어순을 비슷하게 데이터를 만들어 학습할 수도 있고, 번역의 성능을 높이기 위해 다양한 형태로 재구조화 할 수 있다.

# %% [markdown]
# ## Data 2
# [Korean Parallel Corpora](https://github.com/jungyeul/korean-parallel-corpora)에는 Korean-English-jhe, Korean-English-news-v1의 병렬 데이터가 있다.
# - 이 데이터를 다운 받아 Data1의 자료와 합쳐서 사용할 수 있다
# - 이 경우 형태소 분석이 된 경우와 그렇지 않은 자료가 있으니, Data1의 자료와 합칠 때 형태소 분석을 하거나 아니면 어절 단위로 결합하여 할 수도 있다.
# - 전체적인 일관성 및 inference를 위해서 형태소 분석된 것이 더 좋을 수 있는데, 이 경우 형태소 분석되지 않는 데이터는 새로 형태소 분석을 할 필요. 단 형태소 분석 단위가 일치하는지 알아볼 필요. 형태소 분석 단위가 완전히 일치하지 않는다면 가급적 분석단위 일치도가 높은 형태소 분석기를 선택할 필요

# %% [markdown]
# ## 구현,실험 전체적인 설명 및 분석

# %% [markdown]
# ## Your Code

# %%
from tqdm import tqdm
from nltk import Tree

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchtext.legacy import data
from torchtext.legacy import datasets

import numpy as np
from einops import rearrange, reduce

import json # save parsed list

# %%
with open('ko-en.ko.parse','r') as f:
    ko = list(f)

## split 으로 구분할 수 있는 형태로 전처리
# 문장 단위로 분리하기
# 문장 내부에서 token 추출하기

def extract_sentence(token_list):
    '''extract <sent #> sth </sent>'''
    sentence_list = []
    sentence = ''
    in_sentence = False

    for tok in token_list:
        if '<sent' in tok:
            in_sentence = True

        if in_sentence:
            sentence += tok

        if '</sent>' in tok:
            sentence_list.append(sentence)
            in_sentence = False
            sentence = ''
            
    return sentence_list

def extract_token(segment_with_morpheme) -> list:
    '''split token/morpheme|...|token/morpheme'''
    token_list = []
    if '|' in segment_with_morpheme: # multiple token in a sement
        for token in segment_with_morpheme.split(sep = '|'):
            token_list.append(token.split(sep = '/')[0])
        
    else: # multiple token in a sement
        token_list.append(segment_with_morpheme.split(sep = '/')[0])
        
    return token_list

def preprocess(ko):
    processed_sentence_list = []
    sentence_list = extract_sentence(ko)
    
    for sentence in tqdm(sentence_list):
        processed_token_list = []
        for segment in sentence.split(sep = '\n'):
            if '\t' in segment:
                token_with_morpheme = segment.split(sep = '\t')[-1]
                processed_token_list += extract_token(token_with_morpheme)
                
        processed_token_list.insert(0, '<sos>')
        processed_token_list.append('<eos>')
        processed_sentence_list.append(processed_token_list)

    return processed_sentence_list

processed_ko = preprocess(ko)
# Out:
# 100%|██████████| 349874/349874 [00:06<00:00, 57610.25it/s]

# %%
# English data
with open('ko-en.en.parse.syn') as f:
    en = f.readlines()

processed_en = []
for idx, _ in tqdm(enumerate(en)):
    t = Tree.fromstring(en[idx])
    processed_token_list = t.leaves()
    
    processed_token_list.insert(0, '<sos>')
    processed_token_list.append('<eos>')
    
    processed_en.append(processed_token_list)
# Out:
# 330974it [00:27, 12193.65it/s]

# %%
# save parsed dataset
import json

ko_en_json = [{'ko' : ko, 'en' : en} for ko, en in zip(processed_ko[:32*2], processed_en[:32*2])]
with open('ko_en_parsed.json', 'w') as fp:
    json.dump(ko_en_json, fp)
    
# check whether properly saved or not
with open('ko_en_parsed.json', 'r') as fp:
    ko_en = json.loads(next(fp)) #!#
    
# print(ko_en)

# %%
## torchtext 에 전달하기
# json file 로 만들기
ko_en_json = [{'ko' : ko, 'en' : en} for ko, en in zip(processed_ko[:32*2], processed_en[:32*2])]
with open('ko_en_parsed.json', 'w') as fp:
    json.dump(ko_en_json, fp)

KOREAN = data.Field( 
    init_token = '<sos>', 
    eos_token = '<eos>', 
    lower = True, 
    include_lengths = True
)

ENGLISH = data.Field( 
    init_token = '<sos>', 
    eos_token = '<eos>', 
    lower = True
)

fields  = {'ko' : ('ko', KOREAN), 'en' : ('en', ENGLISH)}

train_data, test_data = data.TabularDataset.splits(
                            path  = '/home/enkeejunior1/study_NLP/assignment/Assignment4/', #!#
                            train = 'ko_en_parsed.json',
                            test  = 'ko_en_parsed.json',
                            format = 'json',
                            fields = fields
)

KOREAN.build_vocab(train_data, min_freq = 2)
ENGLISH.build_vocab(train_data, min_freq = 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-ac06bdc58c28> in <module>
#      21                             test  = 'ko_en_parsed.json',
#      22                             format = 'json',
# ---> 23                             fields = fields
#      24 )
#      25
#
# ~/.local/lib/python3.6/site-packages/torchtext/legacy/data/dataset.py in splits(cls, path, root, train, validation, test, **kwargs)
#      76             path = cls.download(root)
#      77         train_data = None if train is None else cls(
# ---> 78             os.path.join(path, train), **kwargs)
#      79         val_data = None if validation is None else cls(
#      80             os.path.join(path, validation), **kwargs)
#
# ~/.local/lib/python3.6/site-packages/torchtext/legacy/data/dataset.py in __init__(self, path, format, fields, skip_header, csv_reader_params, **kwargs)
#     272                 next(reader)
#     273
# --> 274             examples = [make_example(line, fields) for line in reader]
#     275
#     276         if isinstance(fields, dict):
#
# ~/.local/lib/python3.6/site-packages/torchtext/legacy/data/dataset.py in <listcomp>(.0)
#     272                 next(reader)
#     273
# --> 274             examples = [make_example(line, fields) for line in reader]
#     275
#     276         if isinstance(fields, dict):
#
# ~/.local/lib/python3.6/site-packages/torchtext/legacy/data/example.py in fromJSON(cls, data, fields)
#      43
#      44                     v = reduce(reducer, ks, obj)
# ---> 45                     setattr(ex, name, field.preprocess(v))
#      46         return ex
#      47
#
# ~/.local/lib/python3.6/site-packages/torchtext/legacy/data/field.py in preprocess(self, x)
#     209             x = self.tokenize(x.rstrip('\n'))
#     210         if self.lower:
# --> 211             x = Pipeline(str.lower)(x)
#     212         if self.sequential and self.use_vocab and self.stop_words is not None:
#     213             x = [w for w in x if w not in self.stop_words]
#
# ~/.local/lib/python3.6/site-packages/torchtext/legacy/data/pipeline.py in __call__(self, x, *args)
#      35         """
#      36         for pipe in self.pipes:
# ---> 37             x = pipe.call(x, *args)
#      38         return x
#      39
#
# ~/.local/lib/python3.6/site-packages/torchtext/legacy/data/pipeline.py in call(self, x, *args)
#      50         """
#      51         if isinstance(x, list):
# ---> 52             return [self.convert_token(tok, *args) for tok in x]
#      53         return self.convert_token(x, *args)
#      54
#
# ~/.local/lib/python3.6/site-packages/torchtext/legacy/data/pipeline.py in <listcomp>(.0)
#      50         """
#      51         if isinstance(x, list):
# ---> 52             return [self.convert_token(tok, *args) for tok in x]
#      53         return self.convert_token(x, *args)
#      54
#
# TypeError: descriptor 'lower' requires a 'str' object but received a 'list'

# %%
print(vars(train_data.examples[0])['ko'][0])
# Out:
# ['<sos>', '777', '항공편', '은', '1', '시간', '동안', '지상', '에', '머물', '게', '되', 'ㅂ니다', '.', '<eos>']

# %%
BATCH_SIZE = 16

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_iterator, test_iterator = BucketIterator.splits(
    (train_data, test_data), 
     batch_size = BATCH_SIZE,
     sort_within_batch = True,
     sort_key = lambda x : len(x.ko),
     device = device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-7fc0c381954f> in <module>
#       1 BATCH_SIZE = 16
#       2
# ----> 3 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#       4
#       5 train_iterator, test_iterator = BucketIterator.splits(
#
# NameError: name 'torch' is not defined

# %%
# word2vec 으로 embedding 시켜주기

# %%
## model building
# preparation
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
## model 1 : (Packed) Encoder-Decoder

## model 2 : Convolutional Seq to Seq

## model 3 : Transformers

# %%
# Data2
from Korpora import Korpora

Korpora.fetch("korean_parallel_koen_news")
corpus = Korpora.load("korean_parallel_koen_news")

# %%
len(en)
# Out:
# 330974

# %%
with open('ko-en.ko.parse','r') as f:
    ko = list(f)

# %%
len(ko)
# Out:
# 3108134

# %%
ko[6000:7000]
# Out:
# ['1\t2\tNP_OBJ\t영어/NNP\n',
#  '2\t3\tVP\t공부/NNG|하/XSV|러/EC\n',
#  '3\t0\tVP\t오/VV|았/EP|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 638>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t영어/NNP\n',
#  '2\t3\tVP\t공부/NNG|하/XSV|러/EC\n',
#  '3\t0\tVP\t오/VV|았/EP|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 639>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t영어/NNP\n',
#  '2\t0\tVP\t공부/NNG|하/XSV|려고요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 640>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t영어/NNP\n',
#  '2\t3\tVP\t연수/NNG|하/XSV|러/EC\n',
#  '3\t0\tVP\t오/VV|았/EP|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 641>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t영어/NNP\n',
#  '2\t0\tVP\t잘/MAG|하/XSV|시/EP|어요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 642>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_SBJ\t영어/NNP|가/JKS\n',
#  '2\t4\tVP\t서투르/VA|어/EC\n',
#  '3\t4\tNP_AJT\t영어/NNP|로/JKB\n',
#  '4\t5\tVP_MOD\t설명/NNG|하/XSV|ㄹ/ETM\n',
#  '5\t6\tNP_SBJ\t수/NNB\n',
#  '6\t0\tVP\t없/VA|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 643>\n',
#  '<sent 1>\n',
#  '1\t7\tNP_SBJ\t영어/NNP|도/JX\n',
#  '2\t3\tVP_MOD\t서툴/VA|ㄴ/ETM\n',
#  '3\t6\tNP_SBJ\t사람/NNG|이/JKS\n',
#  '4\t5\tVP_MOD\t투숙/NNG|하/XSV|ㄹ/ETM\n',
#  '5\t6\tNP_OBJ\t곳/NNG|도/JX\n',
#  '6\t7\tVP\t정하/VV|지/EC\n',
#  '7\t8\tVP_MOD\t않/VX|으시/EP|었/EP|다는/ETM\n',
#  '8\t0\tVNP\t것/NNB|이/VCP|ㅂ니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 644>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t영어/NNP|로/JKB\n',
#  '2\t3\tVP_MOD\t되/VV|ㄴ/ETM\n',
#  '3\t4\tNP_OBJ\t것/NNB|을/JKO\n',
#  '4\t0\tVP\t주/VV|시/EP|어요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 645>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t영어/NNP|로/JKB\n',
#  '2\t3\tVP_SBJ\t설명/NNG|하/XSV|기/ETN|가/JKS\n',
#  '3\t0\tVP\t어렵/VA|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 646>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t영어/NNP|로/JKB\n',
#  '2\t3\tVP_SBJ\t설명/NNG|하/XSV|기/ETN|가/JKS\n',
#  '3\t0\tVP\t어렵/VA|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 647>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t영어/NNP|를/JKO\n',
#  '2\t3\tVP\t공부/NNG|하/XSV|려고/EC\n',
#  '3\t0\tVP\t하/VX|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 648>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t영어/NNP|를/JKO\n',
#  '2\t3\tVP\t공부/NNG|하/XSV|려고/EC\n',
#  '3\t0\tVP\t하/VX|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 649>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t영어/NNP|를/JKO\n',
#  '2\t3\tVP\t못/MAG|하/XSV|아서/EC\n',
#  '3\t4\tVP_MOD\t설명/NNG|하/XSV|ㄹ/ETM\n',
#  '4\t5\tNP_SBJ\t수/NNB\n',
#  '5\t0\tVP\t없/VA|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 650>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t영어/NNP|를/JKO\n',
#  '2\t4\tVP_AJT\t배우/VV|기/ETN|에/JKB|는/JX\n',
#  '3\t4\tNP_SBJ\t시간/NNG|이/JKS\n',
#  '4\t7\tVP\t부족/NNG|하/XSA|지만/EC|,/SP\n',
#  '5\t6\tNP_AJT\t30/SN|일/NNB|간/NNG\n',
#  '6\t7\tNP_OBJ\t체류/NNG|를/JKO\n',
#  '7\t0\tVP\t허락/NNG|하/XSV|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 651>\n',
#  '<sent 1>\n',
#  '1\t3\tNP_OBJ\t영어/NNP|를/JKO\n',
#  '2\t3\tAP\t잘/MAG\n',
#  '3\t4\tVP\t못/MAG|하/XSV|아/EC\n',
#  '4\t5\tVP\t설명/NNG|하/XSV|기/ETN\n',
#  '5\t0\tVP\t어려운데요/VA|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 652>\n',
#  '<sent 1>\n',
#  '1\t3\tNP_OBJ\t영어/NNP|를/JKO\n',
#  '2\t3\tAP\t잘/MAG\n',
#  '3\t4\tVP\t못/MAG|하/XSV|아/EC\n',
#  '4\t5\tVP_SBJ\t설명/NNG|하/XSV|기/ETN\n',
#  '5\t0\tVP\t힘들/VA|ㄴ/ETM|데요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 653>\n',
#  '<sent 1>\n',
#  '1\t3\tNP_OBJ\t영어/NNP|를/JKO\n',
#  '2\t3\tAP\t잘/MAG\n',
#  '3\t5\tVP\t못/MAG|하/XSV|아서/EC\n',
#  '4\t5\tAP\t자세히/MAG\n',
#  '5\t6\tVP\t설명/NNG|하/XSV|아/EC\n',
#  '6\t7\tVP_MOD\t드리/VX|ㄹ/ETM\n',
#  '7\t8\tNP_SBJ\t수/NNB|가/JKS\n',
#  '8\t0\tVP\t없/VA|네요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 654>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t영어/NNP|를/JKO\n',
#  '2\t3\tVP\t잘/MAG|하/XSV|지/EC\n',
#  '3\t0\tVP\t못하/VX|아요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 655>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t오헤어/NNP\n',
#  '2\t6\tNP_AJT\t공항/NNG|에서/JKB\n',
#  '3\t4\tNP\t오전/NNG\n',
#  '4\t5\tNP\t8/SN|시/NNB\n',
#  '5\t6\tNP_AJT\t20/SN|분/NNB|에/JKB\n',
#  '6\t0\tVP\t출발/NNG|하/XSV|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 656>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t올드/NNG\n',
#  '2\t4\tNP_CNJ\t파/NNG|와/JC\n',
#  '3\t4\tNP\t레미/NNG\n',
#  '4\t5\tNP_AJT\t마틴/NNP|으로/JKB\n',
#  '5\t0\tVP\t부탁/NNG|하/XSV|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 657>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t올드/NNG\n',
#  '2\t4\tNP_CNJ\t파/NNG|와/JC\n',
#  '3\t4\tNP\t레미/NNG\n',
#  '4\t5\tNP_OBJ\t마틴/NNP|을/JKO\n',
#  '5\t0\tVP\t주/VV|시/EP|어요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 658>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t워싱턴/NNP\n',
#  '2\t3\tNP_AJT\t디/NNP|씨/NNB|에/JKB\n',
#  '3\t5\tVP_MOD\t있/VV|는/ETM\n',
#  '4\t5\tNP\t하이얏트/NNG\n',
#  '5\t6\tNP_AJT\t리전시/NNG|에/JKB\n',
#  '6\t7\tVP_MOD\t묵/VV|을/ETM\n',
#  '7\t0\tVNP\t것/NNB|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 659>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t워터게이트/NNP\n',
#  '2\t0\tVNP\t호텔/NNG|이/VCP|요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 660>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t원/NNG|으로/JKB\n',
#  '2\t3\tVP\t계산/NNG|하/XSV|아도/EC\n',
#  '3\t0\tVP\t되/VV|ㄹ/ETM|까요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 661>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t원/NNG|으로/JKB\n',
#  '2\t3\tVP\t내/VV|도/EC\n',
#  '3\t0\tVP\t되/VV|겠/EP|습니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 662>\n',
#  '<sent 1>\n',
#  '1\t3\tNP_OBJ\t원/NNG|을/JKO\n',
#  '2\t3\tNP_AJT\t달러/NNG|로/JKB\n',
#  '3\t4\tVP\t바꾸/VV|어/EC\n',
#  '4\t0\tVP\t주/VX|시/EP|어요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 663>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t원화/NNG\n',
#  '2\t4\tNP\t대/NNB\n',
#  '3\t4\tNP\t달러/NNG\n',
#  '4\t5\tNP_SBJ\t환율/NNG|은/JX\n',
#  '5\t6\tVP\t어떻/VA|게/EC\n',
#  '6\t0\tVP\t되/VV|ㅂ니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 664>\n',
#  '<sent 1>\n',
#  '1\t3\tNP\t원화/NNG\n',
#  '2\t3\tNP\t십만/NR\n',
#  '3\t5\tNP_OBJ\t원/NNB|을/JKO\n',
#  '4\t5\tNP_AJT\t달러/NNG|로/JKB\n',
#  '5\t6\tVP\t환전/NNG|하/XSV|고/EC\n',
#  '6\t0\tVP\t싶/VX|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 665>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t원화/NNG\n',
#  '2\t5\tNP_SBJ\t환율/NNG|이/JKS\n',
#  '3\t5\tAP\t지금/MAG\n',
#  '4\t5\tAP\t얼마나/MAG\n',
#  '5\t0\tVP\t되/VV|ㅂ니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 666>\n',
#  '<sent 1>\n',
#  '1\t4\tNP_SBJ\t원화/NNG|가/JKS\n',
#  '2\t4\tAP\t지금/MAG\n',
#  '3\t4\tNP_AJT\t달러/NNG|로/JKB\n',
#  '4\t0\tVNP\t얼마/NNG|이/VCP|에요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 667>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t원화/NNG|로/JKB\n',
#  '2\t0\tVP\t내/VV|겠/EP|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 668>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t원화/NNG|로/JKB\n',
#  '2\t3\tVP\t내/VV|도/EC\n',
#  '3\t0\tVP\t되/VV|겠/EP|습니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 669>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t원화/NNG|로/JKB\n',
#  '2\t3\tVP\t내/VV|도/EC\n',
#  '3\t0\tVP\t되/VV|나요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 670>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t원화/NNG|로/JKB\n',
#  '2\t3\tVP\t지불/NNG|하/XSV|아도/EC\n',
#  '3\t0\tVP\t되/VV|겠/EP|습니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 671>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t원화/NNG|로/JKB\n',
#  '2\t3\tVP\t지불/NNG|하/XSV|아도/EC\n',
#  '3\t0\tVP\t되/VV|나요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 672>\n',
#  '<sent 1>\n',
#  '1\t3\tNP_OBJ\t원화/NNG|를/JKO\n',
#  '2\t3\tNP_AJT\t달러/NNG|로/JKB\n',
#  '3\t4\tVP\t바꾸/VV|어/EC\n',
#  '4\t0\tVP\t주/VX|시/EP|ㅂ시오/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 673>\n',
#  '<sent 1>\n',
#  '1\t4\tNP_OBJ\t원화/NNG|를/JKO\n',
#  '2\t3\tNP\t미국/NNP\n',
#  '3\t4\tNP_AJT\t달러/NNB|로/JKB\n',
#  '4\t5\tVP\t바꾸/VV|어/EC\n',
#  '5\t0\tVP\t주/VX|시/EP|어요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 674>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_MOD\t원화/NNG|의/JKG\n',
#  '2\t3\tNP_SBJ\t환율/NNG|이/JKS\n',
#  '3\t0\tVNP\t얼마/NNG|이/VCP|ㄴ가요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 675>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t월드/NNG\n',
#  '2\t3\tNP_AJT\t호텔/NNG|에/JKB\n',
#  '3\t4\tVP_MOD\t묵/VV|을/ETM\n',
#  '4\t0\tVNP\t것/NNB|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '<sent 2>\n',
#  '1\t2\tNP_SBJ\t이것/NP|ㄴ/JX\n',
#  '2\t0\tVNP\t전화번호/NNG|고요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 676>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_SBJ\t월스트리트저널/NNP|이/JKS\n',
#  '2\t0\tVP\t있/VV|습니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 677>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t유나이티드/NNG|항공/NNG\n',
#  '2\t4\tNP_AJT\t777/SN|편/NNB|으로/JKB\n',
#  '3\t4\tNP_AJT\tLA/SL|에/JKB\n',
#  '4\t5\tVP_MOD\t가/VV|ㄹ/ETM\n',
#  '5\t0\tVNP\t것/NNB|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 678>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t유나이티드/NNG|항공/NNG\n',
#  '2\t0\tVP\t셰리/NNP|-/SS|존스/NNP|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '<sent 2>\n',
#  '1\t0\tVP\t돕/VV|아/EC|드리/VX|ㄹ/ETM|까요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 679>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t유럽/NNP\n',
#  '2\t3\tNP\t비행/NNG\n',
#  '3\t5\tNP\t시/NNB\n',
#  '4\t5\tNP\t30/SN\n',
#  '5\t7\tNP_SBJ\t마일리지/NNG|가/JKS\n',
#  '6\t7\tNP_CMP\t적립/NNG|이/JKC\n',
#  '7\t0\tVP\t되/VV|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 680>\n',
#  '<sent 1>\n',
#  '1\t3\tNP_SBJ\t유로화/NNG|는/JX\n',
#  '2\t3\tAP\t안/MAG\n',
#  '3\t0\tVP\t되/VV|ㄹ/ETM|까요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 681>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t유로화/NNG|로/JKB\n',
#  '2\t3\tVP\t바꾸/VV|어/EC\n',
#  '3\t0\tVP\t주/VX|시/EP|어요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 682>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_MOD\t유로화/NNG|의/JKG\n',
#  '2\t3\tNP_SBJ\t환율/NNG|은/JX\n',
#  '3\t0\tVNP\t얼마/NNG|이/VCP|ㅂ니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 683>\n',
#  '<sent 1>\n',
#  '1\t0\tVP\t이선영/NNP|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '<sent 2>\n',
#  '1\t2\tNP_SBJ\t이/NP|는/JX\n',
#  '2\t6\tVNP\t성/NNG|이/VCP|고/EC\n',
#  '3\t4\tNP\t비행기/NNG\n',
#  '4\t6\tNP_SBJ\t번호/NNG|는/JX\n',
#  '5\t6\tNP\tOZ/SL\n',
#  '6\t0\tVP\t001/SN|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 684>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t인스턴트/NNG\n',
#  '2\t0\tVNP\t라면/NNG|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 685>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t인터내셔널/NNG\n',
#  '2\t3\tNP_AJT\t호텔/NNG|에/JKB\n',
#  '3\t0\tVP\t머뭅/VV|니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 686>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t인터콘티넨탈/NNP\n',
#  '2\t0\tVNP\t호텔/NNG|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 687>\n',
#  '<sent 1>\n',
#  '1\t0\tVP\t조성환/NNP|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 688>\n',
#  '<sent 1>\n',
#  '1\t0\tVP\t조성환/NNP|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 689>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_OBJ\t중국어/NNP|를/JKO\n',
#  '2\t3\tVP_MOD\t하/VV|ㄹ/ETM\n',
#  '3\t4\tNP_SBJ\t수/NNB\n',
#  '4\t6\tVP_MOD\t있/VV|는/ETM\n',
#  '5\t6\tNP\t탑승/NNG\n',
#  '6\t7\tNP_SBJ\t여승무원/NNG|이/JKS\n',
#  '7\t0\tVP\t있/VV|습니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 690>\n',
#  '<sent 1>\n',
#  '1\t6\tNP_INT\t최수지/NNP|,/SP\n',
#  '2\t3\tNP\t4/SN|월/NNB\n',
#  '3\t6\tNP_AJT\t22/SN|일/NNB\n',
#  '4\t5\tNP\t인천행/NNG\n',
#  '5\t6\tNP\tKE/SL\n',
#  '6\t0\tVP\t37/SN|편/NNB|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 691>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t캐세이/NNP\n',
#  '2\t3\tNP\t패시픽/NNP\n',
#  '3\t4\tNP\t재닛/NNP\n',
#  '4\t0\tNP\t스미스/NNP|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '<sent 2>\n',
#  '1\t0\tVP\t말씀/NNG|하/XSV|시/EP|어요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 692>\n',
#  '<sent 1>\n',
#  '1\t3\tNP\t켄트/NNP\n',
#  '2\t3\tDP\t두/MM\n',
#  '3\t4\tNP_OBJ\t상자/NNG|를/JKO\n',
#  '4\t5\tVP\t사/VV|고/EC\n',
#  '5\t0\tVP\t싶/VX|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 693>\n',
#  '<sent 1>\n',
#  '1\t3\tNP\t코냑/NNG\n',
#  '2\t3\tDP\t두/MM\n',
#  '3\t4\tNP_OBJ\t병/NNG\n',
#  '4\t0\tVP\t주/VV|시/EP|어요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 694>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t코엑스/NNP|에/JKB\n',
#  '2\t3\tVP\t근무/NNG|하/XSV|고/EC\n',
#  '3\t0\tVP\t있/VX|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 695>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t코카콜라/NNG|로/JKB\n',
#  '2\t0\tVP\t주/VV|시/EP|어요/EF|./SF\n',
#  '</sent>\n',
#  '<sent 2>\n',
#  '1\t2\tAP\t얼마나/MAG\n',
#  '2\t0\tVP\t하/VV|죠/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 696>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t퀀타스항공사/NNP\n',
#  '2\t0\tNP\t쥴리/NNP|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '<sent 2>\n',
#  '1\t0\tVP\t말씀/NNG|하/XSV|시/EP|어요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 697>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t크리스찬/NNP\n',
#  '2\t3\tNP\t디오르/NNP\n',
#  '3\t4\tNP_OBJ\t상표/NNG|를/JKO\n',
#  '4\t0\tVP\t원하/VV|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 698>\n',
#  '<sent 1>\n',
#  '1\t3\tNP_AJT\t클린턴/NNP|씨/NNB|와/JKB|는/JX\n',
#  '2\t3\tDP\t어떤/MM\n',
#  '3\t0\tVNP\t관계/NNG|이/VCP|ㅂ니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 699>\n',
#  '<sent 1>\n',
#  '1\t7\tNP_SBJ\t타임지/NNP|가/JKS\n',
#  '2\t3\tDP\t몇/MM\n',
#  '3\t4\tNP_SBJ\t부/NNB\n',
#  '4\t7\tVP\t있/VV|는데/EC\n',
#  '5\t7\tNP_AJT\t그것/NP|과/JKB\n',
#  '6\t7\tNP_OBJ\t담요/NNG|를/JKO\n',
#  '7\t8\tVP\t가지/VV|어다/EC\n',
#  '8\t0\tVP\t드리/VX|겠/EP|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 700>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t토마스/NNP\n',
#  '2\t3\tNP\t쿡/NNP\n',
#  '3\t5\tNP_SBJ\t사무소/NNG|가/JKS\n',
#  '4\t5\tNP_AJT\t어디/NP|에/JKB\n',
#  '5\t0\tVP\t있/VV|습니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 701>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_CNJ\t파리/NNP|,/SP\n',
#  '2\t3\tNP\t서울/NNP\n',
#  '3\t4\tNP_MOD\t간/NNB|의/JKG\n',
#  '4\t5\tNP_OBJ\t좌석/NNG|을/JKO\n',
#  '5\t6\tVP\t예약/NNG|하/XSV|려고/EC\n',
#  '6\t0\tVP\t하/VX|는데요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 702>\n',
#  '<sent 1>\n',
#  '1\t4\tNP_SBJ\t파리/NNP|는/JX\n',
#  '2\t4\tNP_AJT\t서울/NNP|보다/JKB\n',
#  '3\t4\tNP\t9/SN|시간/NNG\n',
#  '4\t0\tVP\t느립/VV|니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 703>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t파리/NNP|에/JKB\n',
#  '2\t3\tVP_MOD\t있/VV|는/ETM\n',
#  '3\t4\tNP_AJT\t노보텔/NNP|에/JKB\n',
#  '4\t5\tVP_MOD\t머무르/VV|ㄹ/ETM\n',
#  '5\t0\tVNP\t것/NNB|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 704>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_CNJ\t파리/NNP|와/JC\n',
#  '2\t3\tNP\t서울/NNP\n',
#  '3\t4\tNP_MOD\t간/NNB|의/JKG\n',
#  '4\t5\tNP_OBJ\t좌석/NNG|을/JKO\n',
#  '5\t6\tVP\t예약/NNG|하/XSV|고/EC\n',
#  '6\t0\tVP\t싶/VX|은데요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 705>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t파운드/NNG|로/JKB\n',
#  '2\t3\tVP\t바꾸/VV|어/EC\n',
#  '3\t0\tVP\t주/VX|시/EP|어요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 706>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_MOD\t파운드/NNG|의/JKG\n',
#  '2\t3\tNP_SBJ\t환율/NNG|은/JX\n',
#  '3\t0\tVNP\t얼마/NNG|이/VCP|ㅂ니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 707>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_MOD\t파운드/NNG|의/JKG\n',
#  '2\t3\tNP_SBJ\t환율/NNG|은/JX\n',
#  '3\t0\tVNP\t얼마/NNG|이/VCP|에요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 708>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t파크/NNG\n',
#  '2\t0\tVNP\t호텔/NNG|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 709>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t포시즌/NNG\n',
#  '2\t0\tNP\t호텔/NNG|에서/JKB|이/VCP|요/EC|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 710>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t프린스/NNP\n',
#  '2\t3\tNP_AJT\t호텔/NNG|에서/JKB\n',
#  '3\t4\tVP_MOD\t숙박/NNG|하/XSV|ㄹ/ETM\n',
#  '4\t0\tVNP\t예정/NNG|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 711>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t플라자/NNG\n',
#  '2\t0\tVNP\t호텔/NNG|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 712>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t필리핀/NNP\n',
#  '2\t4\tNP\t항공/NNG\n',
#  '3\t4\tNP\t에이미/NNP\n',
#  '4\t0\tNP\t스미스/NNP|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '<sent 2>\n',
#  '1\t0\tVP\t말씀/NNG|하/XSV|시/EP|어요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 713>\n',
#  '<sent 1>\n',
#  '1\t3\tIP\t하얏/IC\n',
#  '2\t3\tNP_AJT\t호텔/NNG|에/JKB\n',
#  '3\t4\tVP_MOD\t머물/VV|ㄹ/ETM\n',
#  '4\t0\tVNP\t예정/NNG|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 714>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t하얏트/NNP\n',
#  '2\t0\tVNP\t호텔/NNG|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 715>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t하와/NNP|이발/NNG\n',
#  '2\t3\tNP\t유나이티드/NNG|항공/NNG\n',
#  '3\t0\tVP\t777/SN|편/NNB|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 716>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_CNJ\t하와이/NNP|와/JC\n',
#  '2\t3\tNP\t뉴욕/NNP\n',
#  '3\t6\tNP_AJT\t사이/NNG|에/JKB|는/JX\n',
#  '4\t5\tNP_MOD\t5/SN|시간/NNB|의/JKG\n',
#  '5\t6\tNP_SBJ\t시차/NNG|가/JKS\n',
#  '6\t0\tVP\t있/VV|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 717>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_CNJ\t하와이/NNP|와/JC\n',
#  '2\t3\tNP_MOD\t뉴욕/NNP|의/JKG\n',
#  '3\t4\tNP_SBJ\t시차/NNG|는/JX\n',
#  '4\t0\tVP\t5/SN|시간/NNB|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 718>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_CNJ\t하와이/NNP|와/JC\n',
#  '2\t3\tNP_OBJ\t알래스카/NNP|를/JKO\n',
#  '3\t7\tVP\t제외/NNG|하/XSV|고/EC\n',
#  '4\t7\tNP_SBJ\t미국/NNP|은/JX\n',
#  '5\t6\tNP_MOD\t4/SN|개/NNB|의/JKG\n',
#  '6\t7\tNP_AJT\t시간대/NNG|로/JKB\n',
#  '7\t0\tVP\t나뉩/VV|니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 719>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP_MOD\t서울/NNP|의/JKG\n',
#  '3\t0\tVNP\t국민은행/NNP|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 720>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t4\tNP_OBJ\t원/NNG|을/JKO\n',
#  '3\t4\tNP_AJT\t200/SN|달러/NNB|로/JKB\n',
#  '4\t5\tVP\t환전/NNG|하/XSV|고/EC\n',
#  '5\t0\tVP\t싶/VX|은데요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 721>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t5\tNP_OBJ\t원/NNG|을/JKO\n',
#  '3\t4\tNP\t미국/NNP\n',
#  '4\t5\tNP_AJT\t달러/NNB|로/JKB\n',
#  '5\t6\tVP\t바꾸/VV|어/EC\n',
#  '6\t0\tVP\t주/VX|시/EP|어요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 722>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP_OBJ\t원화/NNG|도/JX\n',
#  '3\t4\tVP\t환전/NNG|하/XSV|아/EC\n',
#  '4\t0\tVP\t줍/VX|니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 723>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP_OBJ\t원화/NNG|를/JKO\n',
#  '3\t4\tVP\t바꾸/VV|고/EC\n',
#  '4\t0\tVP\t싶/VX|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 724>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP_OBJ\t원화/NNG|를/JKO\n',
#  '3\t4\tVP\t환전/NNG|하/XSV|고/EC\n',
#  '4\t0\tVP\t싶/VX|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 725>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP_SBJ\t담배/NNG\n',
#  '3\t0\tVP\t있/VV|습니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 726>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t4\tNP_OBJ\t돈/NNG|은/JX\n',
#  '3\t4\tNP_AJT\t달러/NNG|로/JKB\n',
#  '4\t5\tVP\t바꾸/VV|고/EC\n',
#  '5\t0\tVP\t싶/VX|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 727>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP_MOD\t방문/NNG|의/JKG\n',
#  '3\t4\tNP_SBJ\t목적/NNG|이/JKS\n',
#  '4\t0\tVNP\t무엇/NP|이/VCP|ㅂ니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 728>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP_CNJ\t잡지/NNG|나/JC\n',
#  '3\t4\tNP_SBJ\t신문/NNG\n',
#  '4\t0\tVP\t있/VV|어요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 729>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP\t전통/NNG\n',
#  '3\t0\tVNP\t공예품/NNG|이/VCP|에요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 730>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP\t전통/NNG\n',
#  '3\t5\tNP_SBJ\t음식/NNG|이/JKS\n',
#  '4\t5\tAP\t좀/MAG\n',
#  '5\t0\tVP\t있/VV|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 731>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국돈/NNP\n',
#  '2\t4\tNP_SBJ\t10/SN|,/SP|000/SN|원/NNB|이/JKS\n',
#  '3\t4\tNP_AJT\t달러/NNG|로/JKB\n',
#  '4\t0\tVNP\t얼마/NNG|이/VCP|에요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 732>\n',
#  '<sent 1>\n',
#  '1\t4\tNP_AJT\t한국/NNP|에서/JKB\n',
#  '2\t3\tNP\t10/SN|,/SP|000/SN|원/NNB\n',
#  '3\t4\tNP_OBJ\t정도/NNG\n',
#  '4\t5\tVP\t주/VV|고/EC\n',
#  '5\t6\tVP_MOD\t사/VV|ㄴ/ETM\n',
#  '6\t0\tVNP\t것/NNB|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 733>\n',
#  '<sent 1>\n',
#  '1\t5\tNP_AJT\t한국/NNP|에서/JKB\n',
#  '2\t3\tNP\t10/SN|./SP\n',
#  '3\t4\tNP\t000/SN|원/NNB\n',
#  '4\t5\tNP_OBJ\t정도/NNG\n',
#  '5\t6\tVP\t주/VV|고/EC\n',
#  '6\t7\tVP_MOD\t사/VV|ㄴ/ETM\n',
#  '7\t0\tVNP\t것/NNB|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 734>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_AJT\t한국/NNP|에서/JKB\n',
#  '2\t3\tVP_MOD\t가져오/VV|ㄴ/ETM\n',
#  '3\t5\tNP\t인형/NNG\n',
#  '4\t5\tDP\t몇/MM\n',
#  '5\t6\tNP_SBJ\t개/NNB\n',
#  '6\t0\tVP\t있/VV|습니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 735>\n',
#  '<sent 1>\n',
#  '1\t5\tNP_AJT\t한국/NNP|에서/JKB|는/JX\n',
#  '2\t3\tNP\t만/NR\n',
#  '3\t4\tNP\t원/NNB\n',
#  '4\t5\tNP_OBJ\t정도/NNG\n',
#  '5\t6\tVP_MOD\t하/VV|는/ETM\n',
#  '6\t0\tVNP\t물건/NNG|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 736>\n',
#  '<sent 1>\n',
#  '1\t5\tNP_AJT\t한국/NNP|에서/JKB|는/JX\n',
#  '2\t3\tDP\t아무/MM\n',
#  '3\t5\tNP_AJT\t데/NNB|서/JKB|나/JX\n',
#  '4\t5\tNP_OBJ\t달러/NNG|를/JKO\n',
#  '5\t6\tVP_MOD\t사용/NNG|하/XSV|ㄹ/ETM\n',
#  '6\t7\tNP_SBJ\t수/NNB\n',
#  '7\t0\tVP\t있/VV|나요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 737>\n',
#  '<sent 1>\n',
#  '1\t3\tNP_MOD\t한국/NNP|의/JKG\n',
#  '2\t3\tNP_CNJ\t고추장/NNG|과/JC\n',
#  '3\t0\tVNP\t라면/NNG|이/VCP|ㅂ니다/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 738>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP_SBJ\t대사관/NNG\n',
#  '3\t0\tVP\t어디/NP|죠/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 739>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP\t대사관/NNG\n',
#  '3\t4\tNP_SBJ\t전화번호/NNG|가/JKS\n',
#  '4\t5\tVP\t어떻/VA|게/EC\n',
#  '5\t0\tVP\t되/VV|나요/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 740>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t3\tNP_AJT\t대사관/NNG|에/JKB\n',
#  '3\t4\tVP\t연락/NNG|하/XSV|아/EC\n',
#  '4\t0\tVP\t주/VX|시/EP|ㅂ시오/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 741>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t5\tNP_AJT\t대사관/NNG|에/JKB\n',
#  '3\t5\tNP_OBJ\t전화/NNG|를/JKO\n',
#  '4\t5\tAP\t좀/MAG\n',
#  '5\t6\tVP\t걸/VV|어/EC\n',
#  '6\t0\tVP\t주/VX|시/EP|겠/EP|습니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 742>\n',
#  '<sent 1>\n',
#  '1\t2\tNP\t한국/NNP\n',
#  '2\t4\tNP_AJT\t대사관/NNG|으로/JKB\n',
#  '3\t4\tVP\t어떻/VA|게/EC\n',
#  '4\t0\tVP\t갑/VV|니까/EF|?/SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 743>\n',
#  '<sent 1>\n',
#  '1\t2\tNP_SBJ\t한국말/NNG\n',
#  '2\t3\tVP_MOD\t가능/NNG|하/XSA|ㄴ/ETM\n',
#  '3\t5\tNP_AJT\t델타항공/NNP|직원/NNG|과/JKB\n',
#  '4\t5\tAP\t직접/MAG\n',
#  '5\t6\tVP\t이야기/NNG|하/XSV|고/EC\n',
#  '6\t0\tVP\t싶/VX|어요/EF|./SF\n',
#  '</sent>\n',
#  '</id>\n',
#  '\n',
#  '<id 744>\n',
#  '<sent 1>\n']

# %%
ko[2]
# Out:
# '1\t2\tNP\t777/SN\n'

# %%
t = Tree.fromstring(en[0])
t = Tree.fromstring(ko[0])

#print t.leaves()
print (' '.join(t.leaves()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-561b0febf852> in <module>
#       2
#       3 t = Tree.fromstring(en[0])
# ----> 4 t = Tree.fromstring(ko[0])
#       5
#       6 #print t.leaves()
#
# ~/.local/lib/python3.6/site-packages/nltk/tree.py in fromstring(cls, s, brackets, read_node, read_leaf, node_pattern, leaf_pattern, remove_empty_top_bracketing)
#     682             else:
#     683                 if len(stack) == 1:
# --> 684                     cls._parse_error(s, match, open_b)
#     685                 if read_leaf is not None:
#     686                     token = read_leaf(token)
#
# ~/.local/lib/python3.6/site-packages/nltk/tree.py in _parse_error(cls, s, match, expecting)
#     733             offset = 13
#     734         msg += '\n{}"{}"\n{}^'.format(" " * 16, s, " " * (17 + offset))
# --> 735         raise ValueError(msg)
#     736
#     737     @classmethod
#
# ValueError: Tree.read(): expected '(' but got '<id'
#             at index 0.
#                 "<id 1> "
#                  ^

# %%
# Out:
# 3108134

# %%
## File Processing

# %% [markdown]
# ## Bleu Score

# %% [markdown]
# ## Inference

# %%
## 형태소 분석을 할 경우

sen_list = [
'모든 액체 , 젤 , 에어로졸 등 은 1 커트 짜리 여닫이 투명 봉지 하나 에 넣 어야 하 ㅂ니다 .',
'미안 하 지만 , 뒷쪽 아이 들 의 떠들 는 소리 가 커 어서 , 광화문 으로 가 아고 싶 은데 표 를 바꾸 어 주 시 겠 어요 ?',
'은행 이 너무 멀 어서 안 되 겠 네요 . 현찰 이 필요 하면 돈 을 훔치 시 어요',
'아무래도 분실 하 ㄴ 것 같 으니 분실 신고서 를 작성 하 아야 하 겠 습니다 . 사무실 로 같이 가 시 ㄹ 까요 ?',
'부산 에서 코로나 확진자 가 급증 하 아서 병상 이 부족하 아 지자  확진자 20명 을 대구 로 이송하 ㄴ다 .',
'변기 가 막히 었 습니다 .',
'그 바지 좀 보이 어 주 시 ㅂ시오 . 이거 얼마 에 사 ㄹ 수 있 는 것 이 ㅂ니까 ?',
'비 가 오 아서 백화점 으로 가지 말 고 두타 로 가 았 으면 좋 겠 습니다 .',
'속 이 안 좋 을 때 는 죽 이나 미음 으로 아침 을 대신 하 ㅂ니다',
'문 대통령 은 집단 이익 에서 벗어 나 아 라고 말 하 었 다 .',
'이것 좀 먹어 보 ㄹ 몇 일 간 의 시간 을 주 시 어요 .',
'이날 개미군단 은 외인 의 물량 을 모두 받 아 내 었 다 .',
'통합 우승 의 목표 를 달성하 ㄴ NC 다이노스 나성범 이 메이저리그 진출 이라는 또 다른 꿈 을 향하 어 나아가 ㄴ다 .',
'이번 구조 조정 이 제품 을 효과 적 으로 개발 하 고 판매 하 기 위하 ㄴ 회사 의 능력 강화 조처 이 ㅁ 을 이해 하 아 주 시 리라 생각 하 ㅂ니다 .',
'요즘 이 프로그램 녹화 하 며 많은 걸 느끼 ㄴ다 '
'배낭 여행 은 우리 들 이 어리었을 때 허용 되 지 않 으면 우울 하 아 하 ㄴ다'
'그 소녀 는 단지 늑대 처럼 울부짖 을 수 있 을 뿐 이 었 다']

# %%
## 어절단위로 결합하여 할 경우

sen_list = [
'모든 액체, 젤, 에어로졸 등은 1커트 짜리 여닫이 투명 봉지 하나에 넣어야 합니다.',
'미안하지만 , 뒷쪽 아이들의 떠드는 소리가 커서 , 광화문으로 가고 싶은데 표를 바꾸어 주시겠어요?',
'은행이 너무 멀어서 안되겠네요. 현찰이 필요하면 돈을 훔치세요',
'아무래도 분실한 것 같으니 분실신고서를 작성해야 하겠습니다. 사무실로 같이 가실까요?',
'부산에서 코로나 확진자가 급증해서 병상이 부족해지자  확진자 20명을 대구로 이송한다.',
'변기가 막히었습니다 .',
'그 바지 좀 보여주십시오. 이거 얼마에 살 수 있는 것입니까?',
'비가 와서 백화점으로 가지 말고 두타로 갔으면 좋겠습니다 .',
'속이 안좋을 때는 죽이나 미음으로 아침을 대신 합니다',
'문 대통령은 집단이익에서 벗어나라고 말하였다.',
'이것 좀 먹어 볼 몇 일 간의 시간을 주세요.',
'이날 개미군단은 외인의 물량을 모두 받아내었다.',
'통합 우승의 목표를 달성한 NC 다이노스 나성범이 메이저리그 진출이라는 또다른 꿈을 향해 나아간다.',
'이번 구조 조정이 제품을 효과적으로 개발하고 판매하기 위한 회사의 능력 강화 조처임을 이해해 주시리라 생각합니다.',
'요즘 이 프로그램 녹화하며 많은 걸 느낀다'
'배낭 여행은 우리들이 어렸을 때 허용디지 않으면 우울 해 한다'
'그 소녀는 단지 늑대처럼 울부짖을 수 있을 뿐이었다']
