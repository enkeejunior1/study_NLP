# %% [markdown]
# # Regular Expression
# - Python has a module named re to work with regular expressions. To use it, we need to import the module.

# %% [markdown]
# ## Specify Pattern Using RegEx

# %% [markdown]
# ### MetaCharacters
# Metacharacters are characters that are interpreted in a special way by a RegEx engine. Here's a list of metacharacters:
#
# - [] . ^ $ * + ? {} () \ |

# %% [markdown]
# #### [] - Square brackets
#
# - Square brackets specifies a set of characters you wish to match.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.43.07.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.43.07.png)
# - You can also specify a range of characters using - inside square brackets.
#
#     - [a-e] is the same as [abcde].
#     - [1-4] is the same as [1234].
#     - [0-39] is the same as [01239].
# <br>
# - You can complement (invert) the character set by using caret **^** symbol at the start of a square-bracket.
#
#     - [^abc] means any character except a or b or c.
#     - [^0-9] means any non-digit character.

# %% [markdown]
# #### . - Period
#
# - A period matches any single character (except newline '\n').
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.46.47.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.46.47.png)

# %% [markdown]
# #### ^ - Caret
#
# - The caret symbol ^ is used to check if a string starts with a certain character.
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.47.58.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.47.58.png)

# %% [markdown]
# #### $ - Dollar
#
# - The dollar symbol $ is used to check if a string ends with a certain character.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.49.04.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.49.04.png)

# %% [markdown]
# #### * - Star
#
# - The star symbol * matches zero or more occurrences of the pattern left to it.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.49.56.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.49.56.png)

# %% [markdown]
# #### + - Plus
#
# - The plus symbol + matches one or more occurrences of the pattern left to it.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.50.55.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.50.55.png)

# %% [markdown]
# #### ? - Question Mark
#
# - The question mark symbol ? matches zero or one occurrence of the pattern left to it.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.52.01.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.52.01.png)

# %% [markdown]
# #### {} - Braces
#
# - Consider this code: {n,m}.
# - This means at least n, and at most m repetitions of the pattern left to it.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.53.05.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.53.05.png)
# - Let's try one more example. This RegEx [0-9]{2, 4} matches at least 2 digits but not more than 4 digits
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.53.56.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.53.56.png)

# %% [markdown]
# #### | - Alternation
#
# - Vertical bar | is used for alternation (or operator).
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.54.43.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.54.43.png)

# %% [markdown]
# #### () - Group
#
# - Parentheses () is used to group sub-patterns.
# - For example, (a|b|c)xz match any string that matches either a or b or c followed by xz
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.56.20.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.56.20.png)

# %% [markdown]
# #### \ - Backslash
#
# - Backlash \ is used to escape various characters including all metacharacters. For example,
#
# - \dollar a match if a string contains dollar followed by a.
# - Here, dollar  is not interpreted by a RegEx engine in a special way.
#
# - If you are unsure if a character has special meaning or not, you can put \ in front of it. This makes sure the character is not treated in a special way.

# %% [markdown]
# #### Special Sequences
#
# - Special sequences make commonly used patterns easier to write. Here's a list of special sequences:
# - \A - Matches if the specified characters are at the start of a string.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.59.44.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2010.59.44.png)
# - \b - Matches if the specified characters are at the beginning or end of a word.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.45.44.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.45.44.png)
# - \B - Opposite of \b. Matches if the specified characters are not at the beginning or end of a word.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.46.22.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.46.22.png)
# - \d - Matches any decimal digit. Equivalent to [0-9]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.47.13.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.47.13.png)
# - \D - Matches any non-decimal digit. Equivalent to [^0-9]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.47.49.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.47.49.png)
# - \s - Matches where a string contains any whitespace character. Equivalent to [ \t\n\r\f\v].
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.48.36.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.48.36.png)
# - \S - Matches where a string contains any non-whitespace character. Equivalent to [^ \t\n\r\f\v].
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.49.18.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.49.18.png)
# - \w - Matches any alphanumeric character (digits and alphabets). Equivalent to [a-zA-Z0-9_]. By the way, underscore _ is also considered an alphanumeric character.
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.49.58.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.49.58.png)
# - \W - Matches any non-alphanumeric character. Equivalent to [^a-zA-Z0-9_]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.50.28.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-09-23%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.50.28.png)

# %% [markdown]
# # Regular Expressions in Python

# %%
import re

# %% [markdown]
# ## Using r prefix before RegEx
#
# - When r or R prefix is used before a regular expression, it means raw string.
# - For example, '\n' is a new line whereas r'\n' means two characters: a backslash \ followed by n.
#
# - Backlash \ is used to escape various characters including all metacharacters. However, using r prefix makes \ treat as a normal character.

# %%
s = 'Hi\nHello'
print(s)

# %%
raw_s = r'Hi\nHello'
print(raw_s)

# %%
string = '\nection\n\\n'
print(string)

result = re.findall('\n', string)
#result = re.findall(r'\n', string)
#result = re.findall('\\n', string)
#result = re.findall('\\\\n', string)
#result = re.findall(r'\\n', string)

print(result)

# %% [markdown]
# ## re.findall()
# - The **re.findall()** method returns a list of strings containing all matches.

# %%
# Program to extract numbers from a string
#string = 'hello 12 hi 89. Howdy 34'
string = 'I hate this 34a class. Very much 64. 2389'
pattern = '\d+'
result = re.findall(pattern, string) 
print(result)

# %%
string = 'hello 12 hi 89. Howdy 34, +'
#pattern = '\d+'
#result = re.findall(r'\d+', string) 
result = re.findall('[\d+]', string) 

print(result)

# %% [markdown]
# ## re.split()
# - The **re.split** method splits the string where there is a match and returns a list of strings where the splits have occurred.

# %%
string = 'Twelve:12 Eighty nine:89.'
pattern = '\d+'
result = re.split(pattern, string) 
print(result)

# %% [markdown]
# - You can pass **maxsplit** argument to the re.split() method. It's the maximum number of splits that will occur.
# - the default value of maxsplit is 0; meaning all possible splits.

# %%
string = 'Twelve:12 Eighty nine:89 Nine:9.'
pattern = '\d+'
# maxsplit = 1
# split only at the first occurrence
result = re.split(pattern, string, 1) 
print(result)

# %% [markdown]
# ## re.sub()
# - The syntax of re.sub() is:
# <br>
# re.sub(pattern, replace, string)
# <br>
# - The method returns a string where matched occurrences are replaced with the content of replace variable.
# - If the pattern is no found, re.sub() returns the original string.

# %%
# multiline string
string = 'abc 12\
de 23 \n f45 6'
print(string)
# matches all whitespace characters
pattern = '\s+'
# empty string
replace = ''
new_string = re.sub(pattern, replace, string) 
print(new_string)

# %% [markdown]
# - You can pass count as a fourth parameter to the re.sub() method. If omited, it results to 0. This will replace all occurrences.

# %%
# multiline string
string = 'abc 12\
de 23 \n f45 6'
# matches all whitespace characters
pattern = '\s+'
replace = ''
new_string = re.sub(r'\s+', replace, string, 2) 
print(new_string)

# %% [markdown]
# ## re.subn()
# - The **re.subn()** is similar to re.sub() expect it returns a tuple of 2 items containing the new string and the number of substitutions made.

# %%
# multiline string
string = 'abc 12\
de 23 \n f45 6'
# matches all whitespace characters
pattern = '\s+'
# empty string
replace = ''
new_string = re.subn(pattern, replace, string) 
print(new_string)

# %% [markdown]
# ## re.search()
# - The **re.search()** method takes two arguments: a pattern and a string.
# - The method looks for the first location where the RegEx pattern produces a match with the string.
#
# - If the search is successful, **re.search()** returns a match object; if not, it returns None.

# %%
string = "This class is really boring"
# check if 'Python' is at the beginning
#match = re.search('\ATjis', string)
match = re.search('is', string)
if match:
  print("pattern found inside the string")
  print(match)
else:
  print("pattern not found")

# %% [markdown]
# ## Match object
# - You can get methods and attributes of a match object using dir() function.
#
# - Some of the commonly used methods and attributes of match objects are:

# %% [markdown]
# ### match.group()
# - The *group()* method returns the part of the string where there is a match.

# %%
string = '39801 356, 2102 1111'
# Three digit number followed by space followed by two digit number
pattern = '(\d{3}) (\d{2})'
# match variable contains a Match object.
match = re.search(pattern, string) 
if match:
  print(match.group())
else:
  print("pattern not found")

# %%
print(match.group(1))
print(match.group(2))
print(match.group(1,2))
print(match.groups())

# %% [markdown]
# ### match.start(), match.end() and match.span()
# - The **start()** function returns the index of the start of the matched substring.
# - Similarly, **end()** returns the end index of the matched substring.
# - The **span()** function returns a tuple containing start and end index of the matched part.

# %%
match.start()

# %%
match.end()

# %%
match.span()

# %% [markdown]
# ### match.re and match.string
# - The **re** attribute of a matched object returns a regular expression object.
# - Similarly, **string** attribute returns the passed string.

# %%
match.re

# %%
match.string

# %% [markdown]
# ## Greedy and Lazy match
# - The quantifiers ( * + {}) are greedy operators, so they expand the match as far as they can through the provided text.
# - For example, <.+> matches <div>simple div</div> in This is a <div> simple div</div> test. In order to catch only the div tag we can use a ? to make it lazy:

# %%
string = "This is a <div> simple div</div> test"
# check if 'Python' is at the beginning
match = re.search('<.+>', string)
if match:
  print("pattern found inside the string")
  print(match.group())
else:
  print("pattern not found")

# %% [markdown]
# ## Look-ahead and Look-behind — (?=) and (?<=)
# - d(?=r) : matches a d only if is followed by r, but r will not be part of the overall regex match
# - (?<=r)d : matches a d only if is preceded by an r, but r will not be part of the overall regex match

# %%
string = 'drone'
#string = 'third'
match = re.search('d(?=r)', string)
#match = re.search('(?<=r)d', string)
if match:
  print("pattern found inside the string")
  print(match.group())
else:
  print("pattern not found")
